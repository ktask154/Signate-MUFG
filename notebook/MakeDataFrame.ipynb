# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install category_encoders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting category_encoders
#   Downloading category_encoders-2.5.0-py2.py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 4.5 MB/s
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.7.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.21.6)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.5->category_encoders) (2022.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.5.0

# %%
import os
import pandas as pd
import numpy as np
import re
import string

from sklearn.preprocessing import LabelEncoder
import category_encoders as ce

# %%
DIR = '/content/drive/MyDrive/Competitions/Signate/MUFJ'
INPUT_DIR = os.path.join(DIR,'input')
OUTPUT_DIR = os.path.join(DIR,'output')

# %%
train_df = pd.read_csv(os.path.join(INPUT_DIR,'train.csv'))
test_df = pd.read_csv(os.path.join(INPUT_DIR,'test.csv'))

# %%
display(train_df.head(3))
print(train_df.shape)
display(test_df.head(3))
print(test_df.shape)
# Out:
#             id         goal country  duration category1        category2  \
# 0  train_00000  20001-21000      US        45       art      mixed media
# 1  train_00001  19001-20000      US        59      food      restaurants
# 2  train_00002    2001-3000      US        38       art  performance art
#
#                                         html_content  state
# 0  <div class="contents"><div><p><a href="http://...      1
# 1  <div class="contents"><div><p>Cultural Pretzel...      0
# 2  <div class="contents"><div><p>I want to perfor...      0
# (9791, 8)
#            id       goal country  duration   category1         category2  \
# 0  test_00000  5001-6000      FR        30       dance      performances
# 1  test_00001  6001-7000      GB        23  publishing  children's books
# 2  test_00002  6001-7000      GB        30     theater             plays
#
#                                         html_content
# 0  <div class="contents"><div><p>Bonjour ,</p><p>...
# 1  <div class="contents"><div><p><span class="bol...
# 2  <div class="contents"><div><p>COW is a rural t...
# (9800, 7)

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub('',text)


def remove_html(text):
    html=re.compile(r"<[^>]*?>")
    return html.sub('',text)

def cleaning(texts):
    clean_texts = []
    for text in texts:
        # htmlタグを削除
        text = remove_URL(text)
        text = remove_html(text)
        #アルファベット以外をスペースに置き換え
        #clean_punc = re.sub(r'[^a-zA-Z]', ' ', text)
        #改行削除
        #text = text.replace("\n","")
        clean_texts.append(text)
    return clean_texts

# %%
def get_goal_values(df):
  df["goal"].replace("100000+","100000-100000",inplace=True)
  _df = df["goal"].str.split('-').apply(pd.Series).astype(float)
  _df.columns = ["goal_max","goal_min"]
  df["goal"] = _df.median(axis=1)
  df["goal"] = df["goal"].astype(int)
  return df

# %%
train_len = train_df.shape[0]

concat_df = pd.concat([train_df,test_df],axis=0)
concat_df = concat_df.reset_index(drop=True)

concat_df['content'] = cleaning(concat_df['html_content'])

concat_df = get_goal_values(concat_df)

# %%
concat_df
# Out:
#                 id   goal country  duration     category1         category2  \
# 0      train_00000  20500      US        45           art       mixed media
# 1      train_00001  19500      US        59          food       restaurants
# 2      train_00002   2500      US        38           art   performance art
# 3      train_00003   1500      US        30           art       mixed media
# 4      train_00004   1500      US        29  film & video         webseries
# ...            ...    ...     ...       ...           ...               ...
# 19586   test_09795   4500      US        29         music       world music
# 19587   test_09796  10500      US        30    publishing  children's books
# 19588   test_09797   2500      US        30         music           hip-hop
# 19589   test_09798   7500      US        30       theater             plays
# 19590   test_09799   1500      US        60         music           hip-hop
#
#                                             html_content  state  \
# 0      <div class="contents"><div><p><a href="http://...    1.0
# 1      <div class="contents"><div><p>Cultural Pretzel...    0.0
# 2      <div class="contents"><div><p>I want to perfor...    0.0
# 3      <div class="contents"><div><div class="templat...    1.0
# 4      <div class="contents"><div><p>The story of the...    1.0
# ...                                                  ...    ...
# 19586  <div class="contents"><div><h1 class="page-anc...    NaN
# 19587  <div class="contents"><div><p><span class="bol...    NaN
# 19588  <div class="contents"><div><h1 class="page-anc...    NaN
# 19589  <div class="contents"><div><p>Have you ever re...    NaN
# 19590  <div class="contents"><div><p><span class="bol...    NaN
#
#                                                  content
# 0      The Shillito's Elves attracted close to 100,00...
# 1      Cultural Pretzel Sports Bar is a place where p...
# 2      I want to perform this piece guerilla style, o...
# 3      \n\n\n\n\n\nCanyon de Chelley, Dine' (Navajo) ...
# 4      The story of the show, both on and off screen,...
# ...                                                  ...
# 19586  How Tibetana Started\nIt all began after the t...
# 19587  The Wild Waves Whist is a board book that take...
# 19588
# 19589  Have you ever read a book or seen a movie and ...
# 19590  Our Situation Over the last year, we’ve writte...
#
# [19591 rows x 9 columns]

# %%
def get_num_feature(input_df):
  output_df = pd.DataFrame()
  output_df["ratio_goal_duration"] = input_df["goal"] / input_df["duration"]
  output_df["prod_goal_duration"] = input_df["goal"] * input_df["duration"]
  return output_df

# %%
def get_catg_feature(input_df):
  output_df = pd.DataFrame()
  output_df["category3"] = input_df["category1"] + input_df["category2"]
  output_df["country_category1"] = input_df["country"] + input_df["category1"]
  output_df["country_category2"] = input_df["country"] + input_df["category2"]
  output_df["country_category3"] = input_df["country"] + output_df["category3"]
  return output_df

# %%
def get_ce_feature(input_df):
  _input_df = pd.concat([input_df,
                         get_catg_feature(input_df)]
                        ,axis=1)
  output_df = pd.DataFrame()
  cols = [
      "country",
      "category1",
      "category2",
      "category3",
      "country_category1",
      "country_category2",
      "country_category3"
  ]
  encoder = ce.CountEncoder()
  output_df = encoder.fit_transform(_input_df[cols]).add_prefix("CE_")
  return output_df

# %%
def get_le_feature(input_df):
  _input_df = pd.concat([input_df,
                         get_catg_feature(input_df)]
                        ,axis=1)
  output_df = pd.DataFrame()
  cols = [
      "country",
      "category1",
      "category2"
  ]
  for col in cols:
    encoder =  LabelEncoder()
    output_df[col+"_LE"] = encoder.fit_transform(_input_df[col])
  return output_df

# %%
def get_te_features(input_df):
  _input_df =  pd.concat([
        input_df,
        get_catg_feature(input_df)
    ], axis=1)
  output_df = pd.DataFrame()
  cols = [
      "country",
      "category1",
      "category2",
      "category3",
      "country_category1",
      "country_category2",
      "country_category3"
  ]
  for col in cols:
    target_dict = _input_df[[col,"state"]].groupby(col)["state"].mean().to_dict()
    encoded = _input_df[col].map(lambda x: target_dict[x]).values
    output_df[f"{col}_success_rate"] = encoded
  return output_df

# %%
def text_feature(input_df):
    def total_sentence(x):
        x = x.replace("!", "[end]").replace("?", "[end]").replace(".", "[end]")
        return len(x.split("[end]"))

    input_df['content'] = input_df['content'].astype(str).fillna('missing')
    _df = pd.DataFrame()
    _df['num_chars'] = input_df['content'].apply(len)
    _df['num_words'] = input_df['content'].apply(lambda x: len(x.split())+1)
    _df['num_sentence'] = input_df['content'].apply(lambda x: total_sentence(x))
    _df['num_unique_words'] = input_df['content'].apply(lambda x: len(set(w for w in x.split())))
    _df['words_vs_unique'] = _df['num_unique_words'] / _df['num_words']
    _df['words_vs_chars'] = _df['num_words'] / _df['num_chars']
    _df['chars_vs_sentence'] = _df['num_sentence'] / _df['num_chars']
    _df['words_vs_sentence'] = _df['num_sentence'] / _df['num_words']
    return _df

# %%
def get_html_info(input_df):
    input_df = pd.concat([input_df,text_feature(input_df)],axis=1)
    output_df = pd.DataFrame()
    output_df['num_figure'] = input_df['html_content'].apply(lambda x: x.count('<figure>'))
    output_df['num_video'] = input_df['html_content'].apply(lambda x: x.count('<video>'))
    output_df['num_figure+video'] = output_df['num_figure'] + output_df['num_video']
    output_df['num_figure+video_vs_words'] = output_df['num_figure+video'] / input_df['num_words']
    output_df['count_sent'] = input_df["html_content"].apply(lambda x: len(re.findall("\n",str(x)))+1)

    return output_df

# %%
def get_remove_html_info(input_df):
  input_df = pd.concat([input_df,text_feature(input_df)],axis=1)
  output_df = pd.DataFrame()
  output_df['num_exclamation_marks'] = input_df['content'].apply(lambda x: x.count('!'))
  output_df['num_question_marks'] = input_df['content'].apply(lambda x: x.count('?'))
  output_df['num_punctuation'] = input_df['content'].apply(lambda x: len([c for c in str(x) if c in string.punctuation]))
  output_df["num_words_upper"] = input_df["content"].apply(lambda x: len([w for w in str(x).split() if w.isupper()]))
  output_df["num_words_title"] = input_df["content"].apply(lambda x: len([w for w in str(x).split() if w.istitle()]))
  #output_df["num_stopwords"] = input_df["content"].apply(lambda x: len([w for w in str(x).lower().split() if w in stopwords]))
  output_df['punct_percent'] = output_df['num_punctuation'] / input_df['num_words']
  output_df["mean_word_len"] = input_df["content"].apply(lambda x: np.mean([len(w) for w in str(x).split()]))
  return output_df

# %%
feature_df = pd.concat([
    concat_df,
    get_catg_feature(concat_df),
    get_num_feature(concat_df),
    get_ce_feature(concat_df),
    get_le_feature(concat_df),
    get_te_features(concat_df),
    text_feature(concat_df),
    get_html_info(concat_df),
    get_remove_html_info(concat_df)
    ],axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)

# %%
feature_df
# Out:
#                 id   goal country  duration     category1         category2  \
# 0      train_00000  20500      US        45           art       mixed media
# 1      train_00001  19500      US        59          food       restaurants
# 2      train_00002   2500      US        38           art   performance art
# 3      train_00003   1500      US        30           art       mixed media
# 4      train_00004   1500      US        29  film & video         webseries
# ...            ...    ...     ...       ...           ...               ...
# 19586   test_09795   4500      US        29         music       world music
# 19587   test_09796  10500      US        30    publishing  children's books
# 19588   test_09797   2500      US        30         music           hip-hop
# 19589   test_09798   7500      US        30       theater             plays
# 19590   test_09799   1500      US        60         music           hip-hop
#
#                                             html_content  state  \
# 0      <div class="contents"><div><p><a href="http://...    1.0
# 1      <div class="contents"><div><p>Cultural Pretzel...    0.0
# 2      <div class="contents"><div><p>I want to perfor...    0.0
# 3      <div class="contents"><div><div class="templat...    1.0
# 4      <div class="contents"><div><p>The story of the...    1.0
# ...                                                  ...    ...
# 19586  <div class="contents"><div><h1 class="page-anc...    NaN
# 19587  <div class="contents"><div><p><span class="bol...    NaN
# 19588  <div class="contents"><div><h1 class="page-anc...    NaN
# 19589  <div class="contents"><div><p>Have you ever re...    NaN
# 19590  <div class="contents"><div><p><span class="bol...    NaN
#
#                                                  content  \
# 0      The Shillito's Elves attracted close to 100,00...
# 1      Cultural Pretzel Sports Bar is a place where p...
# 2      I want to perform this piece guerilla style, o...
# 3      \n\n\n\n\n\nCanyon de Chelley, Dine' (Navajo) ...
# 4      The story of the show, both on and off screen,...
# ...                                                  ...
# 19586  How Tibetana Started\nIt all began after the t...
# 19587  The Wild Waves Whist is a board book that take...
# 19588
# 19589  Have you ever read a book or seen a movie and ...
# 19590  Our Situation Over the last year, we’ve writte...
#
#                         category3  ... num_figure+video  \
# 0                  artmixed media  ...                2
# 1                 foodrestaurants  ...                2
# 2              artperformance art  ...                0
# 3                  artmixed media  ...               11
# 4           film & videowebseries  ...               11
# ...                           ...  ...              ...
# 19586            musicworld music  ...                5
# 19587  publishingchildren's books  ...                4
# 19588                musichip-hop  ...                0
# 19589                theaterplays  ...                0
# 19590                musichip-hop  ...                1
#
#       num_figure+video_vs_words count_sent  num_exclamation_marks  \
# 0                      0.011696         32                      0
# 1                      0.012048         11                      1
# 2                      0.000000         12                      0
# 3                      0.041199         62                      0
# 4                      0.044355         66                      5
# ...                         ...        ...                    ...
# 19586                  0.011905        248                      0
# 19587                  0.003373        397                      2
# 19588                  0.000000          1                      0
# 19589                  0.000000         12                      1
# 19590                  0.003802         14                      1
#
#        num_question_marks  num_punctuation  num_words_upper  num_words_title  \
# 0                       0               20                0               20
# 1                       0               28                9               57
# 2                       0               56               20               36
# 3                       0               90               10               33
# 4                       0               59                1               46
# ...                   ...              ...              ...              ...
# 19586                   0               52                4               79
# 19587                   6              180                3              170
# 19588                   0                0                0                0
# 19589                   2               40                2               48
# 19590                   0               51                0               33
#
#        punct_percent  mean_word_len
# 0           0.116959       4.552941
# 1           0.168675       5.327273
# 2           0.150943       4.694595
# 3           0.337079       5.180451
# 4           0.237903       5.129555
# ...              ...            ...
# 19586       0.123810       4.727924
# 19587       0.151771       5.013502
# 19588       0.000000            NaN
# 19589       0.096154       4.640964
# 19590       0.193916       4.732824
#
# [19591 rows x 52 columns]

# %%
def get_agg_func(input_df,col):
  _input_df =  pd.concat([
        input_df,
        get_catg_feature(input_df),
        get_num_feature(input_df)
    ], axis=1)
  output_df = _input_df.groupby(col).agg(
            goal_min=pd.NamedAgg(column="goal", aggfunc="min"),
            goal_max=pd.NamedAgg(column="goal", aggfunc="max"),
            goal_mean=pd.NamedAgg(column="goal", aggfunc="mean"),
            goal_std=pd.NamedAgg(column="goal", aggfunc="std"),
            duration_min=pd.NamedAgg(column="duration", aggfunc="min"),
            duration_max=pd.NamedAgg(column="duration", aggfunc="max"),
            duration_mean=pd.NamedAgg(column="duration", aggfunc="mean"),
            duration_std=pd.NamedAgg(column="duration", aggfunc="std"),
            ratio_goal_durataion_min=pd.NamedAgg(column="ratio_goal_duration", aggfunc="min"),
            ratio_goal_durataion_max=pd.NamedAgg(column="ratio_goal_duration", aggfunc="max"),
            ratio_goal_durataion_mean=pd.NamedAgg(column="ratio_goal_duration", aggfunc="mean"),
            ratio_goal_durataion_std=pd.NamedAgg(column="ratio_goal_duration", aggfunc="std"),
            prod_goal_durataion_min=pd.NamedAgg(column="prod_goal_duration", aggfunc="min"),
            prod_goal_durataion_max=pd.NamedAgg(column="prod_goal_duration", aggfunc="max"),
            prod_goal_durataion_mean=pd.NamedAgg(column="prod_goal_duration", aggfunc="mean"),
            prod_goal_durataion_std=pd.NamedAgg(column="prod_goal_duration", aggfunc="std")
            ).add_prefix(f'{col}_')
  return output_df

country_agg =  get_agg_func(concat_df,"country")
category1_agg =  get_agg_func(concat_df,"category1")
category2_agg =  get_agg_func(concat_df,"category2")
category3_agg =  get_agg_func(concat_df,"category3")
country_category_agg = get_agg_func(concat_df,"country_category1")

# %%
feature_df = feature_df.merge(country_agg,how="left",on="country").merge(category1_agg,how="left",on="category1").merge(category2_agg,how="left",on="category2").merge(category3_agg,how="left",on="category3").merge(country_category_agg,how="left",on="country_category1")
feature_df
# Out:
#                 id   goal country  duration     category1         category2  \
# 0      train_00000  20500      US        45           art       mixed media
# 1      train_00001  19500      US        59          food       restaurants
# 2      train_00002   2500      US        38           art   performance art
# 3      train_00003   1500      US        30           art       mixed media
# 4      train_00004   1500      US        29  film & video         webseries
# ...            ...    ...     ...       ...           ...               ...
# 19586   test_09795   4500      US        29         music       world music
# 19587   test_09796  10500      US        30    publishing  children's books
# 19588   test_09797   2500      US        30         music           hip-hop
# 19589   test_09798   7500      US        30       theater             plays
# 19590   test_09799   1500      US        60         music           hip-hop
#
#                                             html_content  state  \
# 0      <div class="contents"><div><p><a href="http://...    1.0
# 1      <div class="contents"><div><p>Cultural Pretzel...    0.0
# 2      <div class="contents"><div><p>I want to perfor...    0.0
# 3      <div class="contents"><div><div class="templat...    1.0
# 4      <div class="contents"><div><p>The story of the...    1.0
# ...                                                  ...    ...
# 19586  <div class="contents"><div><h1 class="page-anc...    NaN
# 19587  <div class="contents"><div><p><span class="bol...    NaN
# 19588  <div class="contents"><div><h1 class="page-anc...    NaN
# 19589  <div class="contents"><div><p>Have you ever re...    NaN
# 19590  <div class="contents"><div><p><span class="bol...    NaN
#
#                                                  content  \
# 0      The Shillito's Elves attracted close to 100,00...
# 1      Cultural Pretzel Sports Bar is a place where p...
# 2      I want to perform this piece guerilla style, o...
# 3      \n\n\n\n\n\nCanyon de Chelley, Dine' (Navajo) ...
# 4      The story of the show, both on and off screen,...
# ...                                                  ...
# 19586  How Tibetana Started\nIt all began after the t...
# 19587  The Wild Waves Whist is a board book that take...
# 19588
# 19589  Have you ever read a book or seen a movie and ...
# 19590  Our Situation Over the last year, we’ve writte...
#
#                         category3  ... country_category1_duration_mean  \
# 0                  artmixed media  ...                       31.600760
# 1                 foodrestaurants  ...                       33.732731
# 2              artperformance art  ...                       31.600760
# 3                  artmixed media  ...                       31.600760
# 4           film & videowebseries  ...                       32.663082
# ...                           ...  ...                             ...
# 19586            musicworld music  ...                       33.058205
# 19587  publishingchildren's books  ...                       31.835979
# 19588                musichip-hop  ...                       33.058205
# 19589                theaterplays  ...                       30.787500
# 19590                musichip-hop  ...                       33.058205
#
#       country_category1_duration_std  \
# 0                          12.620717
# 1                          11.964994
# 2                          12.620717
# 3                          12.620717
# 4                          11.797912
# ...                              ...
# 19586                      12.137533
# 19587                      10.688245
# 19588                      12.137533
# 19589                      11.947561
# 19590                      12.137533
#
#       country_category1_ratio_goal_durataion_min  \
# 0                                       6.250000
# 1                                       8.333333
# 2                                       6.250000
# 3                                       6.250000
# 4                                       8.333333
# ...                                          ...
# 19586                                   7.936508
# 19587                                   8.333333
# 19588                                   7.936508
# 19589                                   8.333333
# 19590                                   7.936508
#
#        country_category1_ratio_goal_durataion_max  \
# 0                                    12500.000000
# 1                                     5882.352941
# 2                                    12500.000000
# 3                                    12500.000000
# 4                                    20000.000000
# ...                                           ...
# 19586                                11111.111111
# 19587                                 6666.666667
# 19588                                11111.111111
# 19589                                 5642.857143
# 19590                                11111.111111
#
#        country_category1_ratio_goal_durataion_mean  \
# 0                                       244.482430
# 1                                       618.340636
# 2                                       244.482430
# 3                                       244.482430
# 4                                       515.681657
# ...                                            ...
# 19586                                   240.053860
# 19587                                   232.389737
# 19588                                   240.053860
# 19589                                   327.681122
# 19590                                   240.053860
#
#        country_category1_ratio_goal_durataion_std  \
# 0                                      578.729051
# 1                                      764.186355
# 2                                      578.729051
# 3                                      578.729051
# 4                                      899.536571
# ...                                           ...
# 19586                                  531.906690
# 19587                                  446.146770
# 19588                                  531.906690
# 19589                                  599.112506
# 19590                                  531.906690
#
#        country_category1_prod_goal_durataion_min  \
# 0                                            500
# 1                                           1500
# 2                                            500
# 3                                            500
# 4                                           1000
# ...                                          ...
# 19586                                       1500
# 19587                                       3000
# 19588                                       1500
# 19589                                       2000
# 19590                                       1500
#
#        country_category1_prod_goal_durataion_max  \
# 0                                        6000000
# 1                                        6000000
# 2                                        6000000
# 3                                        6000000
# 4                                        6000000
# ...                                          ...
# 19586                                    6000000
# 19587                                    6000000
# 19588                                    6000000
# 19589                                    6000000
# 19590                                    6000000
#
#        country_category1_prod_goal_durataion_mean  \
# 0                                   249136.882129
# 1                                   736182.698515
# 2                                   249136.882129
# 3                                   249136.882129
# 4                                   594444.188428
# ...                                           ...
# 19586                               270520.412288
# 19587                               234223.356009
# 19588                               270520.412288
# 19589                               375081.250000
# 19590                               270520.412288
#
#        country_category1_prod_goal_durataion_std
# 0                                   5.500174e+05
# 1                                   1.047290e+06
# 2                                   5.500174e+05
# 3                                   5.500174e+05
# 4                                   1.054557e+06
# ...                                          ...
# 19586                               6.344851e+05
# 19587                               5.066511e+05
# 19588                               6.344851e+05
# 19589                               8.739281e+05
# 19590                               6.344851e+05
#
# [19591 rows x 132 columns]

# %%
train_feature = feature_df.iloc[:train_len,:]
test_feature = feature_df.iloc[train_len:,:]
test_feature = test_feature.reset_index(drop=True)

train_feature.to_csv(os.path.join(OUTPUT_DIR,"feature_train.csv"),index=False)
test_feature.to_csv(os.path.join(OUTPUT_DIR,"feature_test.csv"),index=False)

display(train_feature.head(3))
display(test_feature.head(3))
# Out:
#             id   goal country  duration category1        category2  \
# 0  train_00000  20500      US        45       art      mixed media
# 1  train_00001  19500      US        59      food      restaurants
# 2  train_00002   2500      US        38       art  performance art
#
#                                         html_content  state  \
# 0  <div class="contents"><div><p><a href="http://...    1.0
# 1  <div class="contents"><div><p>Cultural Pretzel...    0.0
# 2  <div class="contents"><div><p>I want to perfor...    0.0
#
#                                              content           category3  ...  \
# 0  The Shillito's Elves attracted close to 100,00...      artmixed media  ...
# 1  Cultural Pretzel Sports Bar is a place where p...     foodrestaurants  ...
# 2  I want to perform this piece guerilla style, o...  artperformance art  ...
#
#   country_category1_duration_mean country_category1_duration_std  \
# 0                       31.600760                      12.620717
# 1                       33.732731                      11.964994
# 2                       31.600760                      12.620717
#
#   country_category1_ratio_goal_durataion_min  \
# 0                                   6.250000
# 1                                   8.333333
# 2                                   6.250000
#
#    country_category1_ratio_goal_durataion_max  \
# 0                                12500.000000
# 1                                 5882.352941
# 2                                12500.000000
#
#    country_category1_ratio_goal_durataion_mean  \
# 0                                   244.482430
# 1                                   618.340636
# 2                                   244.482430
#
#    country_category1_ratio_goal_durataion_std  \
# 0                                  578.729051
# 1                                  764.186355
# 2                                  578.729051
#
#    country_category1_prod_goal_durataion_min  \
# 0                                        500
# 1                                       1500
# 2                                        500
#
#    country_category1_prod_goal_durataion_max  \
# 0                                    6000000
# 1                                    6000000
# 2                                    6000000
#
#    country_category1_prod_goal_durataion_mean  \
# 0                               249136.882129
# 1                               736182.698515
# 2                               249136.882129
#
#    country_category1_prod_goal_durataion_std
# 0                               5.500174e+05
# 1                               1.047290e+06
# 2                               5.500174e+05
#
# [3 rows x 132 columns]
#            id  goal country  duration   category1         category2  \
# 0  test_00000  5500      FR        30       dance      performances
# 1  test_00001  6500      GB        23  publishing  children's books
# 2  test_00002  6500      GB        30     theater             plays
#
#                                         html_content  state  \
# 0  <div class="contents"><div><p>Bonjour ,</p><p>...    NaN
# 1  <div class="contents"><div><p><span class="bol...    NaN
# 2  <div class="contents"><div><p>COW is a rural t...    NaN
#
#                                              content  \
# 0  Bonjour ,Je m'appelle Morgane Hilgers. Je suis...
# 1  The projectThe hidden world of microorganisms ...
# 2  COW is a rural tragicomedy with songs, written...
#
#                     category3  ... country_category1_duration_mean  \
# 0           danceperformances  ...                       30.000000
# 1  publishingchildren's books  ...                       31.967213
# 2                theaterplays  ...                       30.329897
#
#   country_category1_duration_std country_category1_ratio_goal_durataion_min  \
# 0                       0.000000                                  50.000000
# 1                       9.880551                                   8.333333
# 2                      12.010549                                   8.333333
#
#    country_category1_ratio_goal_durataion_max  \
# 0                                  516.666667
# 1                                 3333.333333
# 2                                 1950.000000
#
#    country_category1_ratio_goal_durataion_mean  \
# 0                                   233.333333
# 1                                   267.040476
# 2                                   140.056098
#
#    country_category1_ratio_goal_durataion_std  \
# 0                                  199.071921
# 1                                  543.368913
# 2                                  222.406743
#
#    country_category1_prod_goal_durataion_min  \
# 0                                      45000
# 1                                       5000
# 2                                       3000
#
#    country_category1_prod_goal_durataion_max  \
# 0                                     465000
# 1                                    3000000
# 2                                    1755000
#
#    country_category1_prod_goal_durataion_mean  \
# 0                               210000.000000
# 1                               249453.551913
# 2                               131907.216495
#
#    country_category1_prod_goal_durataion_std
# 0                              179164.728672
# 1                              472767.270506
# 2                              230673.982419
#
# [3 rows x 132 columns]
