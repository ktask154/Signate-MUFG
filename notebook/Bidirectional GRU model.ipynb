# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import time
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tqdm import tqdm
import math
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn import metrics
import re
import random

import tensorflow as tf
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, CuDNNGRU, Conv1D
from keras.layers import Bidirectional, GlobalMaxPool1D
from keras.models import Model
from keras.models import load_model
from keras import initializers, regularizers, constraints, optimizers, layers
import torch


seed = 42
n_folds = 5

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
DIR = '/content/drive/MyDrive/Competitions/Signate/MUFJ'
INPUT_DIR = os.path.join(DIR,'input')
OUTPUT_DIR = os.path.join(DIR,'output')
OUTPUT_SUB_DIR = os.path.join(OUTPUT_DIR,'submission')
OUTPUT_MODEL_DIR = DIR + '/output/model/GRU/'
if not os.path.exists(OUTPUT_MODEL_DIR):
    os.makedirs(OUTPUT_MODEL_DIR)

# %%
train = pd.read_csv(os.path.join(INPUT_DIR,'train.csv'))
test = pd.read_csv(os.path.join(INPUT_DIR,'test.csv'))
sub = pd.read_csv(os.path.join(INPUT_DIR,'sample_submit.csv'),header=None)
sub.columns = ['id','state']

# %%
display(train.head())
print(train.shape)
display(test.head())
print(test.shape)
display(sub.head())
print(sub.shape)
# Out:
#             id         goal country  duration     category1        category2  \
# 0  train_00000  20001-21000      US        45           art      mixed media
# 1  train_00001  19001-20000      US        59          food      restaurants
# 2  train_00002    2001-3000      US        38           art  performance art
# 3  train_00003    1001-2000      US        30           art      mixed media
# 4  train_00004    1001-2000      US        29  film & video        webseries
#
#                                         html_content  state
# 0  <div class="contents"><div><p><a href="http://...      1
# 1  <div class="contents"><div><p>Cultural Pretzel...      0
# 2  <div class="contents"><div><p>I want to perfor...      0
# 3  <div class="contents"><div><div class="templat...      1
# 4  <div class="contents"><div><p>The story of the...      1
# (9791, 8)
#            id       goal country  duration   category1         category2  \
# 0  test_00000  5001-6000      FR        30       dance      performances
# 1  test_00001  6001-7000      GB        23  publishing  children's books
# 2  test_00002  6001-7000      GB        30     theater             plays
# 3  test_00003  1001-2000      CA        14         art       digital art
# 4  test_00004     1-1000      US        30       music           hip-hop
#
#                                         html_content
# 0  <div class="contents"><div><p>Bonjour ,</p><p>...
# 1  <div class="contents"><div><p><span class="bol...
# 2  <div class="contents"><div><p>COW is a rural t...
# 3  <div class="contents"><div><p>I've been creati...
# 4  <div class="contents"><div><div class="templat...
# (9800, 7)
#            id  state
# 0  test_00000      1
# 1  test_00001      0
# 2  test_00002      0
# 3  test_00003      0
# 4  test_00004      1
# (9800, 2)

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub('',text)


def remove_html(text):
    html=re.compile(r"<[^>]*?>")
    return html.sub('',text)

def cleaning(texts):
    clean_texts = []
    for text in texts:
        # htmlタグを削除
        text = remove_URL(text)
        text = remove_html(text)
        #アルファベット以外をスペースに置き換え
        #clean_punc = re.sub(r'[^a-zA-Z]', ' ', text)
        #改行削除
        #text = text.replace("\n","")
        clean_texts.append(text)
    return clean_texts

# %%
train['html_content'] = cleaning(train['html_content'])
test['html_content'] = cleaning(test['html_content'])

# %%
## some config values 
embed_size = 300 # how big is each word vector
max_features = 50000 # how many unique words to use (i.e num rows in embedding vector)
maxlen = 100 # max number of words in a question to use


## split to train and val
skf = StratifiedKFold(n_splits=n_folds,shuffle=True,random_state=seed)
for fold, ( _, val_) in enumerate(skf.split(train, train.state)):
    train.loc[val_ , "kfold"] = int(fold)
    
train["kfold"] = train["kfold"].astype(int)


preds = []
oof_df = pd.DataFrame()
for fold in range(n_folds):
  print("="*10+f" fold = {fold} "+"="*10)

  train_df = train.loc[train.kfold!=fold]
  val_df = train.loc[train.kfold==fold]

  ## fill up the missing values
  train_X = train_df["html_content"].fillna("_na_").values
  val_X = val_df["html_content"].fillna("_na_").values
  test_X = test["html_content"].fillna("_na_").values

  ## Tokenize the sentences
  tokenizer = Tokenizer(num_words=max_features)
  tokenizer.fit_on_texts(list(train_X))
  train_X = tokenizer.texts_to_sequences(train_X)
  val_X = tokenizer.texts_to_sequences(val_X)
  test_X = tokenizer.texts_to_sequences(test_X)

  ## Pad the sentences 
  train_X = pad_sequences(train_X, maxlen=maxlen)
  val_X = pad_sequences(val_X, maxlen=maxlen)
  test_X = pad_sequences(test_X, maxlen=maxlen)

  ## Get the target values
  train_y = train_df['state'].values
  val_y = val_df['state'].values

  inp = Input(shape=(maxlen,))
  x = Embedding(max_features, embed_size)(inp)
  x = Bidirectional(CuDNNGRU(64, return_sequences=True))(x)
  x = GlobalMaxPool1D()(x)
  x = Dense(16, activation="relu")(x)
  x = Dropout(0.1)(x)
  x = Dense(1, activation="sigmoid")(x)
  model = Model(inputs=inp, outputs=x)
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  model.fit(train_X, train_y, batch_size=512, epochs=3, validation_data=(val_X, val_y))

  pred_noemb_val_y = model.predict([val_X], batch_size=1024, verbose=1)
  pred_noemb_test_y = model.predict([test_X], batch_size=1024, verbose=1)

  val_df['pred_noemb'] = pred_noemb_val_y
  preds.append(pred_noemb_test_y)

  oof_df = pd.concat([oof_df, val_df])

  model.save(OUTPUT_MODEL_DIR+f'GRU_model_fold{fold}.h5')

  del model,train_df,val_df,train_X,val_X,test_X,pred_noemb_val_y,pred_noemb_test_y
# Out:
# ========== fold = 0 ==========
# Epoch 1/3
# 16/16 [==============================] - 4s 83ms/step - loss: 0.6847 - accuracy: 0.5615 - val_loss: 0.6756 - val_accuracy: 0.6452
# Epoch 2/3
# 16/16 [==============================] - 1s 41ms/step - loss: 0.6456 - accuracy: 0.7040 - val_loss: 0.6547 - val_accuracy: 0.6544
# Epoch 3/3
# 16/16 [==============================] - 1s 42ms/step - loss: 0.5882 - accuracy: 0.7464 - val_loss: 0.6090 - val_accuracy: 0.6748
# 2/2 [==============================] - 1s 302ms/step
# 10/10 [==============================] - 0s 36ms/step
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ========== fold = 1 ==========
# Epoch 1/3
# 16/16 [==============================] - 3s 77ms/step - loss: 0.6844 - accuracy: 0.5671 - val_loss: 0.6709 - val_accuracy: 0.6216
# Epoch 2/3
# 16/16 [==============================] - 1s 43ms/step - loss: 0.6439 - accuracy: 0.6948 - val_loss: 0.6448 - val_accuracy: 0.6634
# Epoch 3/3
# 16/16 [==============================] - 1s 42ms/step - loss: 0.5752 - accuracy: 0.7554 - val_loss: 0.5998 - val_accuracy: 0.6788
# 2/2 [==============================] - 0s 304ms/step
# 10/10 [==============================] - 0s 15ms/step
# ========== fold = 2 ==========
# Epoch 1/3
# 16/16 [==============================] - 2s 68ms/step - loss: 0.6859 - accuracy: 0.5598 - val_loss: 0.6768 - val_accuracy: 0.6353
# Epoch 2/3
# 16/16 [==============================] - 1s 43ms/step - loss: 0.6526 - accuracy: 0.6940 - val_loss: 0.6555 - val_accuracy: 0.6302
# Epoch 3/3
# 16/16 [==============================] - 1s 42ms/step - loss: 0.5955 - accuracy: 0.7350 - val_loss: 0.5993 - val_accuracy: 0.6757
# 2/2 [==============================] - 0s 15ms/step
# 10/10 [==============================] - 0s 16ms/step
# ========== fold = 3 ==========
# Epoch 1/3
# 16/16 [==============================] - 2s 65ms/step - loss: 0.6873 - accuracy: 0.5654 - val_loss: 0.6748 - val_accuracy: 0.6420
# Epoch 2/3
# 16/16 [==============================] - 1s 45ms/step - loss: 0.6519 - accuracy: 0.7029 - val_loss: 0.6459 - val_accuracy: 0.6568
# Epoch 3/3
# 16/16 [==============================] - 1s 43ms/step - loss: 0.5861 - accuracy: 0.7540 - val_loss: 0.6018 - val_accuracy: 0.6711
# 2/2 [==============================] - 0s 16ms/step
# 10/10 [==============================] - 0s 15ms/step
# ========== fold = 4 ==========
# Epoch 1/3
# 16/16 [==============================] - 2s 62ms/step - loss: 0.6858 - accuracy: 0.5709 - val_loss: 0.6690 - val_accuracy: 0.6859
# Epoch 2/3
# 16/16 [==============================] - 1s 42ms/step - loss: 0.6436 - accuracy: 0.7076 - val_loss: 0.6317 - val_accuracy: 0.6834
# Epoch 3/3
# 16/16 [==============================] - 1s 42ms/step - loss: 0.5650 - accuracy: 0.7578 - val_loss: 0.5740 - val_accuracy: 0.7140
# 2/2 [==============================] - 0s 15ms/step
# 10/10 [==============================] - 0s 15ms/step

# %%
best_score = 0
best_thresh = 0.5
for thresh in np.arange(0.2, 0.801, 0.01):
    thresh = np.round(thresh, 2)
    score = metrics.f1_score(oof_df.state, (oof_df.pred_noemb>thresh).astype(int))
    print("F1 score at threshold {0} is {1}".format(thresh, score))
    if score > best_score:
      best_score = score
      best_thresh = thresh
print()
print("best F1 score at threshold {0} is {1}".format(best_thresh, metrics.f1_score(oof_df.state, (oof_df.pred_noemb>best_thresh).astype(int))))
# Out:
# F1 score at threshold 0.2 is 0.67994289793005
# F1 score at threshold 0.21 is 0.6826916156890968
# F1 score at threshold 0.22 is 0.6846729107674436
# F1 score at threshold 0.23 is 0.6869189664007028
# F1 score at threshold 0.24 is 0.6902825025883744
# F1 score at threshold 0.25 is 0.6923363928065069
# F1 score at threshold 0.26 is 0.6942584092106254
# F1 score at threshold 0.27 is 0.6958504331965345
# F1 score at threshold 0.28 is 0.6970464135021096
# F1 score at threshold 0.29 is 0.6990532360701537
# F1 score at threshold 0.3 is 0.7012640339169349
# F1 score at threshold 0.31 is 0.7021749484045087
# F1 score at threshold 0.32 is 0.7058634538152609
# F1 score at threshold 0.33 is 0.7073567708333333
# F1 score at threshold 0.34 is 0.7092409240924092
# F1 score at threshold 0.35 is 0.7089452603471295
# F1 score at threshold 0.36 is 0.7096610169491525
# F1 score at threshold 0.37 is 0.7095278969957083
# F1 score at threshold 0.38 is 0.7092495636998256
# F1 score at threshold 0.39 is 0.70911183919242
# F1 score at threshold 0.4 is 0.7069383358764922
# F1 score at threshold 0.41 is 0.7061620040226734
# F1 score at threshold 0.42 is 0.7044399033995913
# F1 score at threshold 0.43 is 0.7016949152542372
# F1 score at threshold 0.44 is 0.7004211332312403
# F1 score at threshold 0.45 is 0.6996590355577204
# F1 score at threshold 0.46 is 0.6951437066402378
# F1 score at threshold 0.47 is 0.6923774040882087
# F1 score at threshold 0.48 is 0.6862885857860731
# F1 score at threshold 0.49 is 0.6775203506574828
# F1 score at threshold 0.5 is 0.6704171531684534
# F1 score at threshold 0.51 is 0.665732154410179
# F1 score at threshold 0.52 is 0.6599496221662468
# F1 score at threshold 0.53 is 0.6514323932671943
# F1 score at threshold 0.54 is 0.6427191087870864
# F1 score at threshold 0.55 is 0.6332252085264134
# F1 score at threshold 0.56 is 0.6210563629918469
# F1 score at threshold 0.57 is 0.6086746987951808
# F1 score at threshold 0.58 is 0.5974950884086444
# F1 score at threshold 0.59 is 0.5833333333333334
# F1 score at threshold 0.6 is 0.5691264867630131
# F1 score at threshold 0.61 is 0.5563068920676203
# F1 score at threshold 0.62 is 0.5418875927889714
# F1 score at threshold 0.63 is 0.523081088398538
# F1 score at threshold 0.64 is 0.5046341126020196
# F1 score at threshold 0.65 is 0.48868138087153373
# F1 score at threshold 0.66 is 0.47118301314459055
# F1 score at threshold 0.67 is 0.4538235294117646
# F1 score at threshold 0.68 is 0.43661971830985913
# F1 score at threshold 0.69 is 0.41852644451238147
# F1 score at threshold 0.7 is 0.393910860012555
# F1 score at threshold 0.71 is 0.36819277108433734
# F1 score at threshold 0.72 is 0.3368490441661174
# F1 score at threshold 0.73 is 0.30236486486486486
# F1 score at threshold 0.74 is 0.27564766839378235
# F1 score at threshold 0.75 is 0.24429909846208236
# F1 score at threshold 0.76 is 0.2157571376942537
# F1 score at threshold 0.77 is 0.1856088560885609
# F1 score at threshold 0.78 is 0.1509433962264151
# F1 score at threshold 0.79 is 0.12194652817849587
# F1 score at threshold 0.8 is 0.09549902152641879
#
# best F1 score at threshold 0.36 is 0.7096610169491525

# %%
oof = train.merge(oof_df[["id","kfold","pred_noemb"]],how='left',on=["id","kfold"])
oof.to_csv(os.path.join(OUTPUT_DIR,"GRUmodel_oof.csv"),index=False)
oof
# Out:
#                id         goal country  duration     category1  \
# 0     train_00000  20001-21000      US        45           art
# 1     train_00001  19001-20000      US        59          food
# 2     train_00002    2001-3000      US        38           art
# 3     train_00003    1001-2000      US        30           art
# 4     train_00004    1001-2000      US        29  film & video
# ...           ...          ...     ...       ...           ...
# 9786  train_09786       1-1000      US        15         music
# 9787  train_09787    3001-4000      CA        30       fashion
# 9788  train_09788      100000+      GB        30    technology
# 9789  train_09789  79001-80000      US        35    technology
# 9790  train_09790    1001-2000      ES        30           art
#
#              category2                                       html_content  \
# 0          mixed media  The Shillito's Elves attracted close to 100,00...
# 1          restaurants  Cultural Pretzel Sports Bar is a place where p...
# 2      performance art  I want to perform this piece guerilla style, o...
# 3          mixed media  \n\n\n\n\n\nCanyon de Chelley, Dine' (Navajo) ...
# 4            webseries  The story of the show, both on and off screen,...
# ...                ...                                                ...
# 9786  electronic music  So the story behind this is that I've been mak...
# 9787     ready-to-wear                       THE HIGH CLOTHINGMy visio...
# 9788          software  We don't think anybody looks forward to fillin...
# 9789           gadgets  \n\n\n\n\n\n\n\n\n\n  \n\n\n\n\n\n\n\n What is...
# 9790    conceptual art  Artyoutube Art inspired in YoutubeMany popular...
#
#       state  kfold  pred_noemb
# 0         1      4    0.551170
# 1         0      3    0.240610
# 2         0      0    0.382052
# 3         1      1    0.738643
# 4         1      2    0.707163
# ...     ...    ...         ...
# 9786      0      2    0.187603
# 9787      0      3    0.150799
# 9788      0      0    0.468017
# 9789      1      0    0.715171
# 9790      0      0    0.531919
#
# [9791 rows x 10 columns]

# %%
predictions =np.mean(preds, axis=0)
test["pred_noemb"] = predictions
test.to_csv(os.path.join(OUTPUT_DIR,"GRUmodel_test.csv"),index=False)
test
# Out:
#               id         goal country  duration   category1         category2  \
# 0     test_00000    5001-6000      FR        30       dance      performances
# 1     test_00001    6001-7000      GB        23  publishing  children's books
# 2     test_00002    6001-7000      GB        30     theater             plays
# 3     test_00003    1001-2000      CA        14         art       digital art
# 4     test_00004       1-1000      US        30       music           hip-hop
# ...          ...          ...     ...       ...         ...               ...
# 9795  test_09795    4001-5000      US        29       music       world music
# 9796  test_09796  10001-11000      US        30  publishing  children's books
# 9797  test_09797    2001-3000      US        30       music           hip-hop
# 9798  test_09798    7001-8000      US        30     theater             plays
# 9799  test_09799    1001-2000      US        60       music           hip-hop
#
#                                            html_content  pred_noemb
# 0     Bonjour ,Je m'appelle Morgane Hilgers. Je suis...    0.306340
# 1     The projectThe hidden world of microorganisms ...    0.594024
# 2     COW is a rural tragicomedy with songs, written...    0.623170
# 3     I've been creating landscape images using crea...    0.281092
# 4     \n\n\n\nIve been making hip hop music for ten ...    0.361561
# ...                                                 ...         ...
# 9795  How Tibetana Started\nIt all began after the t...    0.711607
# 9796  The Wild Waves Whist is a board book that take...    0.678455
# 9797                                                       0.391358
# 9798  Have you ever read a book or seen a movie and ...    0.357092
# 9799  Our Situation Over the last year, we’ve writte...    0.727405
#
# [9800 rows x 8 columns]

# %%
preds2 = []
_df = pd.DataFrame()
for fold in range(n_folds):
  print("="*10+f" fold = {fold} "+"="*10)

  oof_val = oof.loc[oof.kfold==fold]
  oof_train = oof.loc[oof.kfold!=fold]

  ## fill up the missing values
  train_X = oof_train["html_content"].fillna("_na_").values
  val_X = oof_val["html_content"].fillna("_na_").values
  test_X = test["html_content"].fillna("_na_").values

  ## Tokenize the sentences
  tokenizer = Tokenizer(num_words=max_features)
  tokenizer.fit_on_texts(list(train_X))
  val_X = tokenizer.texts_to_sequences(val_X)
  test_X = tokenizer.texts_to_sequences(test_X)

  ## Pad the sentences 
  val_X = pad_sequences(val_X, maxlen=maxlen)
  test_X = pad_sequences(test_X, maxlen=maxlen)

  #inp = Input(shape=(maxlen,))
  #x = Embedding(max_features, embed_size)(inp)
  #x = Bidirectional(CuDNNGRU(64, return_sequences=True))(x)
  #x = GlobalMaxPool1D()(x)
  #x = Dense(16, activation="relu")(x)
  #x = Dropout(0.1)(x)
  #x = Dense(1, activation="sigmoid")(x)
  #model = Model(inputs=inp, outputs=x)
  #model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  model = load_model(OUTPUT_MODEL_DIR+f'GRU_model_fold{fold}.h5')

  pred_noemb_val_y = model.predict([val_X], batch_size=1024, verbose=1)
  pred_noemb_test_y = model.predict([test_X], batch_size=1024, verbose=1)

  oof_val['pred_noemb'] = pred_noemb_val_y
  preds2.append(pred_noemb_test_y)

  _df = pd.concat([_df, oof_val])

  del model,oof_train,oof_val,val_X,test_X,pred_noemb_val_y,pred_noemb_test_y
# Out:
# ========== fold = 0 ==========
# 2/2 [==============================] - 0s 17ms/step
# 10/10 [==============================] - 0s 17ms/step
# ========== fold = 1 ==========
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2/2 [==============================] - 0s 15ms/step
# 10/10 [==============================] - 0s 15ms/step
# ========== fold = 2 ==========
# 2/2 [==============================] - 0s 15ms/step
# 10/10 [==============================] - 0s 15ms/step
# ========== fold = 3 ==========
# 2/2 [==============================] - 0s 16ms/step
# 10/10 [==============================] - 0s 16ms/step
# ========== fold = 4 ==========
# 2/2 [==============================] - 0s 15ms/step
# 10/10 [==============================] - 0s 15ms/step

# %%
best_score = 0
best_thresh = 0.5
for thresh in np.arange(0.2, 0.801, 0.01):
    thresh = np.round(thresh, 2)
    score = metrics.f1_score(_df.state, (_df.pred_noemb>thresh).astype(int))
    print("F1 score at threshold {0} is {1}".format(thresh, score))
    if score > best_score:
      best_score = score
      best_thresh = thresh
print()
print("best F1 score at threshold {0} is {1}".format(best_thresh, metrics.f1_score(_df.state, (_df.pred_noemb>best_thresh).astype(int))))
# Out:
# F1 score at threshold 0.2 is 0.67994289793005
# F1 score at threshold 0.21 is 0.6826916156890968
# F1 score at threshold 0.22 is 0.6846729107674436
# F1 score at threshold 0.23 is 0.6869189664007028
# F1 score at threshold 0.24 is 0.6902825025883744
# F1 score at threshold 0.25 is 0.6923363928065069
# F1 score at threshold 0.26 is 0.6942584092106254
# F1 score at threshold 0.27 is 0.6958504331965345
# F1 score at threshold 0.28 is 0.6970464135021096
# F1 score at threshold 0.29 is 0.6990532360701537
# F1 score at threshold 0.3 is 0.7012640339169349
# F1 score at threshold 0.31 is 0.7021749484045087
# F1 score at threshold 0.32 is 0.7058634538152609
# F1 score at threshold 0.33 is 0.7073567708333333
# F1 score at threshold 0.34 is 0.7092409240924092
# F1 score at threshold 0.35 is 0.7089452603471295
# F1 score at threshold 0.36 is 0.7096610169491525
# F1 score at threshold 0.37 is 0.7095278969957083
# F1 score at threshold 0.38 is 0.7092495636998256
# F1 score at threshold 0.39 is 0.70911183919242
# F1 score at threshold 0.4 is 0.7069383358764922
# F1 score at threshold 0.41 is 0.7061620040226734
# F1 score at threshold 0.42 is 0.7044399033995913
# F1 score at threshold 0.43 is 0.7016949152542372
# F1 score at threshold 0.44 is 0.7004211332312403
# F1 score at threshold 0.45 is 0.6996590355577204
# F1 score at threshold 0.46 is 0.6951437066402378
# F1 score at threshold 0.47 is 0.6923774040882087
# F1 score at threshold 0.48 is 0.6862885857860731
# F1 score at threshold 0.49 is 0.6775203506574828
# F1 score at threshold 0.5 is 0.6704171531684534
# F1 score at threshold 0.51 is 0.665732154410179
# F1 score at threshold 0.52 is 0.6599496221662468
# F1 score at threshold 0.53 is 0.6514323932671943
# F1 score at threshold 0.54 is 0.6427191087870864
# F1 score at threshold 0.55 is 0.6332252085264134
# F1 score at threshold 0.56 is 0.6210563629918469
# F1 score at threshold 0.57 is 0.6086746987951808
# F1 score at threshold 0.58 is 0.5974950884086444
# F1 score at threshold 0.59 is 0.5833333333333334
# F1 score at threshold 0.6 is 0.5691264867630131
# F1 score at threshold 0.61 is 0.5563068920676203
# F1 score at threshold 0.62 is 0.5418875927889714
# F1 score at threshold 0.63 is 0.523081088398538
# F1 score at threshold 0.64 is 0.5046341126020196
# F1 score at threshold 0.65 is 0.48868138087153373
# F1 score at threshold 0.66 is 0.47118301314459055
# F1 score at threshold 0.67 is 0.4538235294117646
# F1 score at threshold 0.68 is 0.43661971830985913
# F1 score at threshold 0.69 is 0.41852644451238147
# F1 score at threshold 0.7 is 0.393910860012555
# F1 score at threshold 0.71 is 0.36819277108433734
# F1 score at threshold 0.72 is 0.3368490441661174
# F1 score at threshold 0.73 is 0.30236486486486486
# F1 score at threshold 0.74 is 0.27564766839378235
# F1 score at threshold 0.75 is 0.24429909846208236
# F1 score at threshold 0.76 is 0.2157571376942537
# F1 score at threshold 0.77 is 0.1856088560885609
# F1 score at threshold 0.78 is 0.1509433962264151
# F1 score at threshold 0.79 is 0.12194652817849587
# F1 score at threshold 0.8 is 0.09549902152641879
#
# best F1 score at threshold 0.36 is 0.7096610169491525

# %%
a = np.mean(preds2, axis=0)
a
# Out:
# array([[0.30634007],
#        [0.59402406],
#        [0.6231698 ],
#        ...,
#        [0.391358  ],
#        [0.3570916 ],
#        [0.72740537]], dtype=float32)
